# %% [markdown]
# # Data Analysis Workshop
#
# In this notebook, you'll load, clean, merge, analyze, and visualize real-world data using pandas, NumPy, and matplotlib.
#
# The `data/` folder contains three CSV files:
# - `orders.csv` — Sales orders (has quality issues!)
# - `customers.csv` — Customer reference data
# - `products.csv` — Product catalog

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Load and Explore the Data
#
# Load all three CSVs with `pd.read_csv()`. Use `.head()`, `.info()`, `.describe()`, and `.shape` to understand what you're working with.

# %%
# Load the datasets

# %% [markdown]
# ## Step 2: Clean the Data
#
# The orders dataset has several quality issues:
# - Missing values in some columns
# - Duplicate rows
# - Inconsistent date formats
# - Negative quantities (data entry errors)
# - Extra whitespace in string fields
#
# Fix each issue and verify your cleaning worked.

# %%
# Clean the orders data

# %% [markdown]
# ## Step 3: Merge Datasets
#
# Join orders with customers and products to create a single analysis DataFrame.

# %%
# Merge datasets

# %% [markdown]
# ## Step 4: Analyze and Aggregate
#
# Compute business metrics:
# - Revenue by category
# - Top customers by total spend
# - Monthly sales trends
# - Profit margins (revenue - cost)

# %%
# Group and aggregate

# %% [markdown]
# ## Step 5: Visualize
#
# Create a 4-panel dashboard:
# 1. Line chart — monthly revenue trend
# 2. Bar chart — revenue by category
# 3. Scatter — quantity vs unit price
# 4. Histogram — order value distribution

# %%
# Create visualizations
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Your charts here

plt.tight_layout()
plt.savefig('dashboard.png', dpi=150)
plt.show()
